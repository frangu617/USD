# %% [markdown]
# # Assignment 2.1
#
# Name:  Francisco Gutierrez
# Date: 9/14/2026

# %% [markdown]
# For this assignment, you will refer to the textbook to solve the practice exercises. **Use Python to answer any coding problems (not R, even if indicated in your textbook).** Use Jupyter Notebook, Google Colab, or a similar software program to complete your assignment. Submit your answers as a **PDF or HTML** file. As a best practice, always label your axes and provide titles for any graphs generated on this assignment. Round all quantitative answers to 2 decimal places.

# %% [markdown]
# ## Problem # 2.1.

# %% [markdown]
# For the rain simulation example in Section 2.1.1, but with probability of rain 0.30 on any
# given day, simulate the outcome (a) on the next day, (b) the next 10 days. (c) Simulate the
# proportion of days of rain for the next (i) 100 days, (ii) 10,000 days, (iii) 1,000,000 days. Use
# the simulation to explain the long-run relative frequency definition of probability.

# %% [markdown]
# `(a) Your answer goes here`

# %%
For a simulation of just the next day, the outcome is either 0 or 1: 0 if it does not rain and 1 if it rains. Even though the probability of rain is 0.30, we cannot predict with certainty what will happen on a single day.

# %% [markdown]
# `(b) Your answer goes here`

# %%
For the next 10 days, the simulation results vary more. After running the simulation many times, I observed outcomes ranging from 0 to 7 rainy days. Since there are only 10 days in each simulation, the proportion of rainy days can vary considerably from the expected probability of 30%. Across repeated simulations, however, the results tend to center around 3 rainy days out of 10.

# %% [markdown]
# `(c) Your answer goes here`

# %%
For (i) 100 days, my simulation resulted in 28 rainy days, or 28%. For (ii) 10,000 days, the proportion of rainy days was 30.14%. For (iii) 1,000,000 days, the proportion was even closer to the theoretical probability, at 29.99%.

# %% [markdown]
# ## Problem # 2.2.

# %% [markdown]
# Data analysts often implement statistical inference methods by setting the probability of a
# correct inference equal to 0.95. Let *A* denote the event that an inference for the population
# about men is correct. Let *B* represent the event of a corresponding inference about women
# being correct. Suppose that these are independent events.

# %% [markdown]
# (a) Find the probability that (i) *both* inferences are correct, (ii) *neither* inference is correct.
# (b) Construct the probability distribution for *Y* = number of correct inferences.
# (c) With what probability would each inference need to be correct in order for the probability to be 0.95 that *both* are correct?

# %% [markdown]
# `(a) Your answer goes here`

# %%
(a)

(i) The probability that both inferences are correct can be found using the multiplication rule for independent events:

P(A and B) = P(A) × P(B)

= (0.95)(0.95)

= 0.9025

Therefore, the probability that both inferences are correct is 0.9025.

(ii) The probability that each inference is incorrect is found using the complement rule:

P(Aᶜ) = 1 − P(A)

= 1 − 0.95

= 0.05

Since the two events are independent, the probability that neither inference is correct is:

P(Aᶜ and Bᶜ) = P(Aᶜ) × P(Bᶜ)

= (0.05)(0.05)

= 0.0025

Therefore, the probability that neither inference is correct is 0.0025.

(b)

Let Y represent the number of correct inferences. The possible values of Y are 0, 1, and 2.

For Y = 0, neither inference is correct:

P(Y = 0) = (0.05)(0.05)

= 0.0025

For Y = 1, exactly one inference is correct. This can happen in two ways: A is correct and B is incorrect, or A is incorrect and B is correct.

P(Y = 1) = P(A)P(Bᶜ) + P(Aᶜ)P(B)

= (0.95)(0.05) + (0.05)(0.95)

= 0.095

For Y = 2, both inferences are correct:

P(Y = 2) = P(A)P(B)

= (0.95)(0.95)

= 0.9025

Therefore, the probability distribution is:

P(Y = 0) = 0.0025

P(Y = 1) = 0.095

P(Y = 2) = 0.9025

(c)

Let p represent the probability that each individual inference is correct. Since the inferences are independent, the probability that both are correct is:

p × p = 0.95

p² = 0.95

p = √0.95

p ≈ 0.97468

Therefore, each inference would need a probability of approximately 0.97468, or 97.47%, of being correct in order for the probability that both are correct to equal 0.95.

# %% [markdown]
# `(b) Your answer goes here`

# %%
To construct the probability distribution for Y = number of correct inferences, we first identify the possible outcomes. Y = 0 means neither inference is correct, Y = 1 means one inference is correct, and Y = 2 means both inferences are correct.

The probability distribution is as follows:

For Y = 0:

P(Y=0) = P(Aᶜ)P(Bᶜ)

= (0.05)(0.05)

= 0.0025

For Y = 1:

P(Y=1) = P(A)P(Bᶜ) + P(Aᶜ)P(B)

= (0.95)(0.05) + (0.05)(0.95)

= 0.0475 + 0.0475

= 0.095

For Y = 2:

P(Y=2) = P(A)P(B)

= (0.95)(0.95)

= 0.9025

Therefore, the probability distribution is:

P(Y=0) = 0.0025

P(Y=1) = 0.095

P(Y=2) = 0.9025

# %% [markdown]
# `(c) Your answer goes here`

# %%
The probability needed for each inference to be correct so that both are correct with probability 0.95 can be found by letting p represent the probability that each inference is correct.

p × p = 0.95

p² = 0.95

p = √0.95

p ≈ 0.97468

Therefore, each inference must have a probability of approximately 0.97468, or 97.47%, of being correct so that the probability that both are correct is 0.95.

# %% [markdown]
# ## Problem # 2.4.

# %% [markdown]
# A wine connoisseur is asked to match five glasses of red wine with the bottles from which they
# came, representing five different grape types.

# %% [markdown]
# (a) Set up a sample space for the five guesses.
# (b) With random guessing, find the probability of getting all five correct.

# %% [markdown]
# `(a) Your answer goes here`

# %% [markdown]
# If the grape types are labeled A, B, C, D, and E, then the sample space S consists of all possible permutations of A, B, C, D, and E. The number of possible outcomes is:
#
# 5! = 5 × 4 × 3 × 2 × 1 = 120
#
# Therefore, the sample space contains 120 possible outcomes.

# %% [markdown]
# `(b) Your answer goes here`

# %%
The probability of getting all five matches correct with random guessing is:

P(all five correct) = 1/120

which is approximately 0.00833, or 0.833%.

# %% [markdown]
# ## Problem # 2.15.

# %% [markdown]
# Each week an insurance company records *Y* = number of payments because of a home burning
# down. State conditions under which we would expect *Y* to approximately have a Poisson
# distribution.

# %% [markdown]
# `Your answer goes here`

# %% [markdown]
# We would expect Y to approximately have a Poisson distribution if house-fire payments occur independently of one another, if two fires are unlikely to occur at exactly the same time, and if the average rate of house-fire payments remains approximately constant from week to week.

# %% [markdown]
# ## Problem # 2.16.

# %% [markdown]
# Each day a hospital records the number of people who come to the emergency room for treatment.

# %% [markdown]
# (a)  In the first week, the observations from Sunday to Saturday are 10, 8, 14, 7, 21, 44, 60.
# Do you think that the Poisson distribution might describe the random variability of this
# phenomenon adequately. Why or why not?
# (b) Would you expect the Poisson distribution to better describe, or more poorly describe,
# the number of weekly admissions to the hospital for a rare disease? Why?

# %% [markdown]
# `(a) Your answer goes here`

# %%
No, the Poisson distribution may not describe the data adequately because the rate of ER visits does not appear constant across the week, particularly because of the unusually high counts of 44 and 60.

# %% [markdown]
# `(b) Your answer goes here`

# %%
Yes, because the Poisson distribution is often used for rare events that occur independently at a relatively constant rate over a fixed period of time.

# %% [markdown]
# ## Problem # 2.17.

# %% [markdown]
# An instructor gives a course grade of B to students who have total score on exams and homeworks between 800 and 900, where the maximum possible is 1000. If the total scores have
# approximately a normal distribution with mean 830 and standard deviation 50, about what proportion of the students receive a B?

# %% [markdown]
# `Your answer goes here`

# %%
The approximate proportion of students who receive a B is about 64.5%

# %% [markdown]
# ## Problem # 2.20.

# %% [markdown]
# Create a data file with the income values in the `Income` data file linked on the Module 2 Readings page.

# %% [markdown]
# (a) Construct a histogram or a smooth-curve approximation for the *pdf* of income in the
# corresponding population by plotting results using the density function in R (explained
# in Exercise 1.18).
# (b)  Of the probability distributions studied in this chapter, which do you think might be
# most appropriate for these data? Why? Plot the probability function of that distribution
# having the same mean and standard deviation as the income values. Does it seem to
# describe the income distribution well?

# %% [markdown]
# `(a) `
# ![histogram by income](histogram_2_20.svg)

# %% [markdown]
# `(b) Your answer goes here`

# %%
The gamma distribution seems most appropriate because income is positive and the histogram is skewed to the right. Most observations fall in the lower income intervals, while a few large incomes create a long right tail. The gamma distribution can represent this asymmetry, whereas the normal distribution is symmetric and permits negative values.

# %% [markdown]
# ## Problem # 2.21.

# %% [markdown]
# Plot the gamma distribution by fixing the shape parameter *k* = 3 and setting the scale parameter
# = 0.5, 1, 2, 3, 4, 5. What is the effect of increasing the scale parameter? (See also Exercise 2.48.)

# %% [markdown]
# !![gamma distribution](gamma_scale_2_21.svg)

# %% [markdown]
# ## Problem # 2.22.

# %% [markdown]
# Consider the mammogram diagnostic example in Section 2.1.4.

# %% [markdown]
# (a) Show that the joint probability distribution of diagnosis and disease status is as shown in
# Table 2.6. Given that a diagnostic test result is positive, explain how this joint distribution
# shows that the 12% of incorrect diagnoses for the 99% of women not having breast cancer
# swamp the 86% of correct diagnoses for the 1% of women actually having breast cancer.
#
# (b) The first test for detecting HIV-positive status had a sensitivity of 0.999 and specificity
# of 0.9999. Explain what these mean. If at that time 1 in 10,000 men were truly HIV-positive,
# find the positive predictive value. Based on this example, explain the potential disadvantage
# of routine diagnostic screening of a population for a rare disease.
#
# **Table 2.6.** Joint probability distribution for disease status and diagnosis of breast-cancer
# mammogram, based on conditional probabilities in Table 2.1.
#
# $$
# \begin{array}{lccc}
# \textbf{Disease Status} & \textbf{Positive (+)} & \textbf{Negative (–)} & \textbf{Total} \\
# \hline
# \text{Yes }(D) & 0.0086 & 0.0014 & 0.01 \\
# \text{No }(D^c) & 0.1188 & 0.8712 & 0.99 \\
# \hline
# \end{array}
# $$

# %% [markdown]
# (a) To get the values in the table, I multiplied the percentage of women in each group by their chance of getting a positive or negative result:
# - Has cancer and tests positive: (0.01 x 0.86 = 0.0086).
# - Has cancer and tests negative: (0.01 x 0.14 = 0.0014).
# - Does not have cancer and tests positive: (0.99 x 0.12 = 0.1188).
# - Does not have cancer and tests negative: (0.99 x 0.88 = 0.8712).
#
# For example, out of 10,000 women, about 86 would correctly test positive, while 1,188 would test positive even though they do not have cancer. This happens because there are many more women without cancer than with cancer. Even though 12% sounds small compared with 86%, it applies to a much larger group, so the incorrect positive results greatly outnumber the correct ones.
#
# (b) A sensitivity of 0.999 means the test correctly gives a positive result for 99.9% of men who have HIV. A specificity of 0.9999 means it correctly gives a negative result for 99.99% of men who do not have HIV.
# To make this easier to picture, imagine 1,000,000 men. If 1 in 10,000 has HIV:
# - 100 have HIV, and about 100 would test positive.
# - 999,900 do not have HIV, but about 100 would still test positive by mistake.
# The positive predictive value is:
# \[
# \frac{0.999(0.0001)}
# {0.999(0.0001)+0.0001(0.9999)}
# \approx 0.4998=\boxed{49.98\%}.
# \]This means that, under the example’s assumptions, about half of the positive results would be correct.
# The disadvantage of screening for a rare disease is that even a very accurate test can produce many false positives. These results can cause unneces

# %% [markdown]
# ## Problem # 2.27.

# %% [markdown]
# The distribution of *X* = heights *(cm)* of women in the U.K. is approximately *N*(162, $7^2$).
# Conditional on *X = x*, suppose *Y* = weight *(kg)* has a *N*(3.0 + 0.40x, $8^2$) distribution. Simulate
# and plot 1000 observations from this approximate bivariate normal distribution. Approximate
# the marginal means and standard deviations for *X* and *Y*. Approximate and interpret the
# correlation.

# %% [markdown]
# ![height and weight](height_weight_2_27.svg)
#
# I simulated 1,000 height and weight pairs and made a scatterplot. The average height was approximately 162.27 cm, with a standard deviation of 7.08 cm. The average weight was approximately 68.24 kg, with a standard deviation of 8.35 kg.
# The correlation was approximately 0.35, showing a positive relationship: taller women tended to weigh more. However, the points are fairly spread out, so women of similar heights can have quite different weights. These results will vary slightly with each new simulation.

# %% [markdown]
# ## Bayes’ Theorem and AI Decision Reliability

# %% [markdown]
# An autonomous drone uses an onboard AI to detect whether an area contains a **target object** (for example, a missing person wearing a bright jacket).
# The system raises an alert when it believes a target is present. However, the model is not perfect.
#
# - $P(\text{Target}) = 0.03$
# - $P(\text{Alert} \mid \text{Target}) = 0.95$
# - $P(\text{Alert} \mid \text{No Target}) = 0.10$
#
# ### Tasks
#
# 1. **Compute the probability of an alert**
#
#    Use the law of total probability:
#    $$P(\text{Alert}) = P(\text{Alert} \mid \text{Target})P(\text{Target}) + P(\text{Alert} \mid \text{No Target})P(\text{No Target})$$
#
#
#
# 2. **Compute the posterior probability**
#
#    Apply Bayes’ theorem.
#
# $$P(\text{Target} \mid \text{Alert}) =
# \frac{P(\text{Alert} \mid \text{Target})P(\text{Target})}{P(\text{Alert})}$$
#
#
#
# 3. **Implement in Python**
#
#    Write a short script that calculates and prints both probabilities with clear labels.
#
# 4. **Interpret your result**
#
#    In a short paragraph (as a code comment), explain what your computed $(P(\text{Target} \mid \text{Alert})$ means about the AI's reliability when it triggers an alert.
#
# 5. **Bonus**
#
#    Create a function that allows a user to change:
#    - $P(\text{Target})$
#    - $P(\text{Alert} \mid \text{Target})$
#    - $P(\text{Alert} \mid \text{No Target})$
#
#    Then return the updated posterior probability and show how the result changes when $P(\text{Target}) = 0.005$.

# %% [markdown]
# ### Starter Code

# %%
# Bayes' Theorem and AI Decision Reliability

P_target = 0.03
P_alert_given_target = 0.95
P_alert_given_no_target = 0.10

P_no_target = 1 - P_target

# Probability of any alert: correct alerts plus false alarms
P_alert = (
    P_alert_given_target * P_target
    + P_alert_given_no_target * P_no_target
)

# Probability a target is present, given an alert
P_target_given_alert = (
    P_alert_given_target * P_target
) / P_alert

print(f"Probability of an alert: {P_alert:.2%}")
print(f"Probability of a target given an alert: {P_target_given_alert:.2%}")

# Interpretation:
# When the AI raises an alert, there is about a 22.71% chance
# that a target is actually present. That means about 77.29%
# of alerts are false alarms. Although the AI detects 95% of
# actual targets, targets are uncommon, so false alarms from
# areas without targets outnumber the correct alerts.


# Bonus: change the probabilities and calculate the updated result
def bayes_posterior(p_target, p_alert_given_target, p_alert_given_no_target):
    p_alert = (
        p_alert_given_target * p_target
        + p_alert_given_no_target * (1 - p_target)
    )

    if p_alert == 0:
        raise ValueError("The posterior is undefined when alerts cannot occur.")

    return (p_alert_given_target * p_target) / p_alert

# Let the user enter new probabilities.
print("\nEnter probabilities between 0 and 1.")
print("For example, enter 0.03 for 3%.")

try:
    p_target = float(input("Probability of a target: "))
    p_detection = float(input("Probability of an alert when a target is present: "))
    p_false_alarm = float(input("Probability of an alert when no target is present: "))

    if not all(0 <= p <= 1 for p in (p_target, p_detection, p_false_alarm)):
        raise ValueError("Each probability must be between 0 and 1.")

    result = bayes_posterior(p_target, p_detection, p_false_alarm)
    print(f"\nProbability of a target given an alert: {result:.2%}")

except ValueError as error:
    print(f"Invalid input: {error}")
bonus_result = bayes_posterior(0.005, 0.95, 0.10)
print(f"Probability of a target given an alert when prevalence is 0.5%: {bonus_result:.2%}")

# When targets become even rarer, the chance that an alert is
# correct drops from about 22.71% to 4.56%, even though the
# AI's detection and false-alarm rates stay the same.
