# %% [markdown]
# # Assignment 1.1

# %% [markdown]
# Name:
# Date:

# %% [markdown]
# For this assignment, you will refer to the textbook to solve the practice exercises. **Use Python to answer any coding problems (not R, even if indicated in your textbook).** Use Jupyter Notebook, Google Colab, or a similar software program to complete your assignment. Submit your answers as a **PDF or HTML** file. As a best practice, always label your axes and provide titles for any graphs generated on this assignment. Round all quantitative answers to 2 decimal places.

# %% [markdown]
# ## **Problem # 1.1.**
# In the 2018 election for Senate in California, a CNN exit poll of 1882 voters stated that 52.5% voted for the Democratic candidate, Diane Feinstein. Of all 11.1 million voters, 54.2% voted for Feinstein.
#
# (a) What was the (i) subject, (ii) sample, (iii) population?

# %% [markdown]
# `(a) Your answer goes here`

# %%
(i) the subject was every individual voter, (II) the sample was 1882 voters, (iii) the population was 11.1 million voters

# %% [markdown]
# ## **Problem # 1.2.**
# The `Students` data file at [http://stat4ds.rwth-aachen.de/data/Students.dat](http://stat4ds.rwth-aachen.de/data/Students.dat) responses of a class of 60
# social science graduate students at the University of Florida to a questionnaire that asked about *gender* (1 = female, 0 = male), *age*, *hsgpa* = high school GPA (on a four-point scale), cogpa = college GPA, *dhome* = distance (in miles) of the campus from your home town, *dres* = distance (in miles) of the classroom from your current residence, *tv* = average number of hours per week that you watch TV, *sport* = average number of hours per week that you participate in sports or have other physical exercise, *news* = number of
# times a week you read a newspaper, *aids* = number of people you know who have died from AIDS or who
# are HIV+, *veg* = whether you are a vegetarian (1 = yes, 0 = no), *affil* = political affiliation (1 = Democrat, 2
# = Republican, 3 = independent), *ideol* = political ideology (1 = very liberal, 2 = liberal, 3 = slightly liberal, 4
# = moderate, 5 = slightly conservative, 6 = conservative, 7 = very conservative), *relig* = how often you
# attend religious services (0 = never, 1 = occasionally, 2 = most weeks, 3 = every week), *abor* = opinion
# about whether abortion should be legal in the first three months of pregnancy (1 = yes, 0 = no), *affirm* =
# support affirmative action (1 = yes, 0 = no), and *life* = belief in life after death (1 = yes, 2 = no, 3 =
# undecided). You will use this data file for some exercises in this book.

# %% [markdown]
# (a) Practice accessing a data file for statistical analysis with your software by going to the book’s
#      website and copying and then displaying this data file.

# %% [markdown]
# (a)
# subject gender age hsgpa cogpa dhome dres tv sport news aids veg affil ideol relig abor affirm life
# 1     0  32  2.2  3.5  0     5.0  3   5  0   0  0  2  6  2  0  0  1
# 2     1  23  2.1  3.5  1200  0.3  15  7  5   6  1  1  2  1  1  1  3
# 3     1  27  3.3  3.0  1300  1.5  0   4  3   0  1  1  2  2  1  1  3
# 4     1  35  3.5  3.2  1500  8    5   5  6   3  0  3  4  1  1  1  2
# 5     0  23  3.1  3.5  1600  10   6   6  3   0  0  3  1  0  1  0  2
# 6     0  39  3.5  3.5  350   3    4   5  7   0  1  1  2  1  1  1  3
# 7     0  24  3.6  3.7   0    .2   5  12  4   2  0  3  2  1  1  1  1
# 8     1  31  3.0  3.0  5000  1.5  5   3  3   1  0  3  2  1  1  1  1
# 9     0  34  3.0  3.0  5000  2    7   5  3   0  0  3  1  1  1  1  3
# 10    0  28  4.0  3.1  900   2    1   1  2   1  1  3  3  0  0  1  1
# 11    0  23  2.3  2.6  253   1.5  10 15  1   1  0  2  5  1  0  1  1
# 12    1  27  3.5  3.6  190   3    14  3  7   0  0  1  2  1  1  1  3
# 13    0  36  3.3  3.5  245   1.5  6  15 12   5  0  1  1  1  1  1  1
# 14    0  28  3.2  3.2  500   6    3  10  1   2  0  3  4  1  1  0  1
# 15    1  28  3.0  3.5  3500  1    4   3  1   0  0  1  1  0  1  1  1
# 16    1  25  3.8  3.3  210   10   7   6  1   0  1  3  2  3  1  1  1
# 17    1  41  4.0  3.0  1000  15   6   7  3  10  0  3  3  3  0  0  1
# 18    0  50  3.8  3.8  0     3    5   9  6  10  0  1  2  0  1  0  2
# 19    0  71  4.0  3.5  5000  3    6  12  2   2  0  3  2  0  1  0  2
# 20    1  28  3.0  3.8  120   1    25  0  0   2  1  1  1  1  1  1  1
# 21    1  26  3.7  3.7  8000  8    4   4  4   1  0  3  4  1  1  1  1
# 22    1  27  4.0  3.7  2     2.5  4   2  7   0  0  3  2  1  1  1  1
# 23    0  31  2.7  3.5  1700  5    7   7  2   0  0  2  7  3  0  0  1
# 24    1  23  3.7  3.7  2     2    7   4  2   0  0  3  4  0  1  1  1
# 25    0  23  3.2  3.8  450   4    0   7  7   3  0  3  1  0  1  1  1
# 26    1  44  3.0  3.0  0     2    2   3  2   3  1  3  3  2  1  1  1
# 27    0  26  3.7  3.0  1000  3    8   2  7   0  0  1  2  1  1  1  3
# 28    1  31  3.7  3.8  850  10    10  3  7   0  0  2  5  2  1  0  1
# 29    0  24  3.3  3.1  420   2    10  6  5   0  0  1  4  1  1  1  3
# 30    1  26  3.3  3.3  1200  .75  10  0  3   0  0  2  2  1  1  1  3
# 31    0  26  3.3  3.5  1000  1.5  0   3  3   3  1  1  2  1  1  1  2
# 32    1  32  3.5  3.9  150  12    10  2  0   0  0  1  2  1  0  0  1
# 33    0  26  3.4  3.4  2000  1.5  2   7 14   0  0  1  2  0  1  1  2
# 34    1  22  3.2  2.8  316  2     10  3  5   2  0  3  2  1  1  1  3
# 35    1  24  3.5  3.9  900  1.75  8   0  0   1  0  1  1  1  1  1  3
# 36    0  24  3.6  3.3  250   2    4   6  3   1  0  2  5  3  0  1  1
# 37    0  23  3.8  3.7  180  .5    10  5  7   0  0  3  2  0  1  0  3
# 38    0  33  3.4  3.4  6000  1.5  8   5  6   2  0  3  2  0  1  1  2
# 39    0  23  2.8  3.2  950   2    37  10 5   0  0  2  5  2  1  0  1
# 40    0  31  3.8  3.5  1100  .75  .5  3  5   2  0  2  6  2  1  0  3
# 41    0  26  3.4  3.4  1300  1.2  0   8  2   0  0  3  2  1  0  1  2
# 42    0  28  2.0  3.0  360  .25  10   8  3   0  0  1  3  0  1  1  3
# 43    1  24  3.8  3.9  1800  2    2   5  4   1  0  2  6  3  0  1  1
# 44    0  23  3.0  3.6  900   15  12   0  5   0  0  2  5  0  1  0  2
# 45    1  25  3.0  4.0  5000  5   1.5  0  4   0  0  3  4  1  1  1  2
# 46    1  24  3.0  3.5  300   1   10   5  5   0  0  1  2  0  1  1  2
# 47    1  27  3.0  3.8  2000  20  28   7 14   2  1  2  3  1  1  1  1
# 48    0  24  3.3  3.8  630   1.3  2   3  5   0  0  2  7  3  0  0  1
# 49    1  26  3.8  4.0  1200  1    0   4  3   1  0  1  2  0  1  1  2
# 50    1  27  3.0  4.0  580   2    5  15  1   2  0  1  1  1  1  1  2
# 51    0  32  3.0  3.0  2000  5    5   5  2   1  0  2  5  3  0  1  1
# 52    1  41  4.0  4.0  0     8    8   4  2   2  0  2  4  1  0  0  1
# 53    1  29  3.0  3.9  300  3.7   2   5  1  11  0  1  2  1  1  1  1
# 54    1  50  3.5  3.8  6    6     7   3  7   0  0  1  2  1  1  1  3
# 55    1  22  3.4  3.7  80   7    10   1  2   2  0  3  2  0  1  1  3
# 56    1  23  3.6  3.2  375  1.5  5    10 5   0  0  2  6  3  0  0  1
# 57    0  26  3.5  3.6  2000  .3  16   8  3   0  0  1  4  1  1  1  3
# 58    0  30  3.0  3.0  1    1.1  1    4  3   0  0  3  3  3  1  0  1
# 59    1  23  3.0  3.0  112  .5   15   3  3   0  0  3  4  2  1  1  1
# 60    1  22  3.4  3.0  650  4    8   16  7   1  0  3  4  1  1  1  1

# %% [markdown]
# (b) Using responses on *abor*, state a question that could be addressed with (i) descriptive
#      statistics, (ii) inferential statistics.

# %% [markdown]
# (i) descriptive statistics, using the responses on abor, would be "What is the average age of an abortion supporter?"
#
# (ii) inferential statistics, using the responses on abor, would be "Is there a relationship between abortion support and age?"

# %% [markdown]
# ## **Problem # 1.3.**
# Identify each of the following variables as categorical or quantitative: (a) Number of smartphones that you own; (b) County of residence; (c) Choice of diet (vegetarian, nonvegetarian); (d) Distance, in kilometers, commute to work

# %% [markdown]
# (a) The number of smartphones that you own would be quantitative.
#
# (b) The county of residence would be categorical.
#
# (c) The choice of diet would be categorical.
#
# (d) The distance, in kilometers, commute to work would be quantitative.

# %% [markdown]
# ## **Problem # 1.4.**
# Give an example of a variable that is (a) categorical; (b) quantitative; (c) discrete; (d) continuous

# %% [markdown]
# (a) If any, the brand of smartphone you own would be categorical.
#
# (b) The screen size of your smartphone would be quantitative.
#
# (c) The number of smartphones that you own would be discrete.
#
# (d) The number of hours you spend on your phone daily would be continuous.

# %% [markdown]
# ## **Problem # 1.10.**
# Analyze the `Carbon_West` ([http://stat4ds.rwth-aachen.de/data/Carbon_West.dat](http://stat4ds.rwth-aachen.de/data/Carbon_West.dat)) data file at the book’s website by **(a)** constructing a frequency distribution and  a histogram, **(b)** finding the mean, median, and standard deviation. Interpret each.

# %% [markdown]
# `(a)`

# %% [markdown]
# `(b) Your answer goes here`

# %% [markdown]
# ## **Problem # 1.11.**
# According to Statistics Canada, for the Canadian population having income in 2019, annual income had a median of `$`35,000 and mean of `$`46,700. What would you predict about the shape of the distribution? Why?

# %% [markdown]
# I would predict that the income distribution is skewed to the right, because the median is greater than the mean, meaning that a few people that make a lot of money would skew the graph to the right as opposed to many people on the left that make less money

# %% [markdown]
# ## **Problem # 1.13.**
# A report indicates that public school teacher’s annual salaries in New York city have an approximate  mean of `$`69,000 and standard deviation of `$`6,000. If the distribution has approximately a bell shape, report intervals that contain about (a) 68%, (b) 95%, (c) all or nearly all salaries. Would a salary of  `$`100,000 be unusual? Why?

# %% [markdown]
# (a) About 68%: within 1 standard deviation
# $69,000 ± $6,000 → $63,000 to $75,000
# (b) About 95%: within 2 standard deviations
# $69,000 ± $12,000 → $57,000 to $81,000
# (c) All or nearly all (about 99.7%): within 3 standard deviations
# $69,000 ± $18,000 → $51,000 to $87,000
#
# A salary of $100,000 would be very unusual because it is:
#
# (100,000 - 6,000)/(6,000) is about 5.17
#
# That is more than 5 standard deviations above the mean, well outside the interval containing nearly all salaries.

# %% [markdown]
# ## **Problem # 1.17.**
# From the `Murder` data file ([http://stat4ds.rwth-aachen.de/data/Murder.dat](http://stat4ds.rwth-aachen.de/data/Murder.dat)) at the book’s website, use the variable murder, which is the murder rate (per 100,000 population) for each state in the U.S. in 2017 according to the FBI Uniform Crime Reports. At first, do not use the observation for D.C. (DC). Using software:
# (a) Find the mean and standard deviation and interpret their values.
# (b) Find the five-number summary, and construct the corresponding box plot. Interpret.
# (c) Now include the observation for D.C. What is affected more by this outlier: The mean or the median? The range or the inter-quartile range?

# %% [markdown]
# **Answer:**

# %% [markdown]
# `(a) Your answer goes here`

# %%
Without including D.C. the mean is 4.874, and the standard deviation is 2.586

# %% [markdown]
# `(b) Your answer goes here`

# %%
Minimum = 1
q1 =2.6
median = 4.85
q3 = 6.2
maximum = 12.4

# %% [markdown]
# `(c) Your answer goes here`

# %%
what is most affected by the outlier is the mean, going up by 0.38 where the median only went up 0.15. The range is larger, havint the minimum at 1 and maximum at 24.2, where the inter-quatile range only went up by 0.5

# %% [markdown]
# ## **Problem # 1.18.**
# The `Income` data file ([http://stat4ds.rwth-aachen.de/data/Income.dat](http://stat4ds.rwth-aachen.de/data/Income.dat)) at the book’s website reports annual income values in the U.S., in thousands of dollars.
#
# (a) Using software, construct a histogram. Describe its shape.
# (b) Find descriptive statistics to summarize the data. Interpret them.
# (c) The kernel density estimation method finds a smooth-curve approximation for a histogram. At each value, it takes into account how many observations are nearby and their distance, with more weight given those closer. Increasing the bandwidth increases the influence of observations further away. Plot a smooth-curve approximation for the histogram of income values. Summarize the impact of increasing and of decreasing the bandwidth substantially from the default value.
# (d) Construct and interpret side-by-side box plots of income by race (B = Black, H = Hispanic, W = White).  Compare the incomes using numerical descriptive statistics

# %% [markdown]
# **Answer:**

# %% [markdown]
# `(a) Your answer goes here`

# %%
The histogram is right skewed.

# %% [markdown]
# `(b) Your answer goes here`

# %%
the descriptive statistics are as follow:
    Total Rows = 80, The sample size.
    Lower Whisker = 16, Minimum value within 1.5 × IQR of Q1
    First Quartile (Q1) = 22, Median of the lower half of the data
    Median = 30, Middle value of the data
    Interquartile Range (IQR) = 25, Difference between Q3 and Q1
    Third Quartile (Q3) = 50, Median of the upper half of the data
    Upper Whisker = 84, Maximum value within 1.5 × IQR of Q3
    Outliers = 84, 104, 120, Values falling beyond the whisker

# %% [markdown]
# `(c) Your answer goes here`

# %%
The default kernel density curve shows that the income distribution is concentrated primarily around the lower income values and has a long right tail caused by a few high incomes. Decreasing the bandwidth produces a less smooth, more irregular curve with several narrow peaks. It emphasizes individual values and small variations in the data but may treat random variation as meaningful. Increasing the bandwidth produces a wider and smoother curve with fewer peaks. It makes the overall shape easier to see but can hide important features of the distribution. Therefore, the default bandwidth provides a compromise between showing detail and producing a smooth representation of the income distribution.

# %% [markdown]
# `(d) Your answer goes here`

# %% [markdown]
# ## **Problem # 1.19.**
# The `Houses` data file ([http://stat4ds.rwth-aachen.de/data/Houses.dat](http://stat4ds.rwth-aachen.de/data/Houses.dat)) at the book’s website lists the selling price (thousands of dollars), size (square feet), tax bill (dollars), number of bathrooms, number of bedrooms, and whether the house is new (1 = yes, 0 = no) for 100 home sales in Gainesville, Florida. Let’s analyze the selling prices.
#
# (a) Construct a frequency distribution and a histogram. Describe the shape.
# (b) Find the percentage of observations that fall within one standard deviation of the mean. Why is this not close to 68%?
# (c) Construct a box plot, and interpret.
# (d) Use descriptive statistics to compare selling prices according to whether the house is new.

# %% [markdown]
# **Answer:**

# %% [markdown]
# `(a) Your answer goes here`

# %%
The frequency distributiion seems very right-skewed, with:
    51% of homes sold for under 200
    39% sold between 200 and 400
    Only 10% sold for 400 or more
    A few very expensive homes stretch all the way into the 800–1,000 range

# %% [markdown]
# `(b) Your answer goes here`

# %%
about 85% of the observations fall within one sample standard deviation of the mean. That's because this distribution is strongly right-skewed rather than bell-shaped.

# %% [markdown]
# `(c) Your answer goes here`

# %%
The box plot shows that the data is strongly right-skewed, most homes are clustered at the lower end of the price range. 
    Q1 ≈ 139, meaning about 25% of homes sold below this price.
    Median ≈ 199, meaning half sold below about 199 and half above.
    Q3 ≈ 255–258, meaning about 75% sold below this price.
    The middle 50% of selling prices therefore falls roughly between 139 and 257.
    The lower whisker extends to about 31.5, while the upper whisker reaches roughly 435.
    Several values above roughly 500 are shown as high-price outliers, reaching as high as about 880.5.

# %% [markdown]
# `(d) Your answer goes here`

# %%
The descriptive statistics indicate that new houses tend to sell for substantially higher prices than non-new houses

# %% [markdown]
# ## **AI Problem: Preparing Data for Healthcare Predictions**
#
# AI in healthcare thrives on clean, insightful data prep: models like random forests predict gallstones from features like BMI and age, but garbage in = garbage out. Here, you'll perform EDA on the Gallstone-1 dataset to spot patterns, directly informing AI steps like feature scaling or class balancing. This is your first taste of how stats prevent biased predictions in tools saving lives, like FDA-approved AI diagnostics flagging risks pre-surgery.
#
# ### Dataset
# UCI's Gallstone-1 [https://www.kaggle.com/datasets/xixama/gallstone-dataset-uci?resource=download]. Load gallstone.xlsx (~320 rows).
#
# ### Tasks
#
# (a) Feature Exploration
# Load data. Show first 5 rows and info. Summarize key features and their distributions. Explain what these findings reveal about the data's central tendencies and variability, and how they might inform initial AI preprocessing decisions, such as normalization.
#
# (b) Exploratory Data Analysis
# Conduct a deeper analysis on key features and their relationship to `gallstone status`. Prepare a brief report on your findings. Include at least 5 clean, well-formatted visualizations.
#
# (c) Data Augmentation
# Generate 50 synthetic "augmented" rows for gallstone-present cases. Append, re-run your analysis in part (b). How does augmentation smooth variances, mimicking real GANs for underrepresented classes?

# %% [markdown]
# **Answer:**

# %% [markdown]
# `(a) Your answer goes here`

# %% [markdown]
# `(b) Your answer goes here`

# %% [markdown]
# `(c) Your answer goes here`
